# %% [markdown]
# <a href="https://colab.research.google.com/github/ANadalCardenas/attention/blob/main/lab_synth_data_with_llms_todo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Synthetic data generation with LLMs
#
# This Lab session leverages the capabilities of Large Language Models (LLMs) to generate synthetic data. It is built upon the [LangChain](https://python.langchain.com/docs/get_started/introduction) framework.
#
# ## Key Features
# - **Flexible LLM Integration**: In this case we will use  [Ollama](https://ollama.com/)  following the guidance available on the [LangChain Quickstart Guide](https://python.langchain.com/docs/get_started/quickstart#llm-chain).
# - **Customizable Data Generation**: Users can tailor the synthetic data generation process through a set of predefined constants, allowing for the adjustment of shop type, the number of categories, vendors, and products, as well as the retry logic for product detail generation.
#
# ## Workflow
# - **Film Genre List Generation**: Initiates the process by creating a list of unique film genres to review.
# - **Synthetic Film Reviews Generation**: For each film genre, a detailed review is generated, including the reasons to like or dislike a film from such genre.
#
# ## Interactivity and Customization
# Designed within the interactive environment of a Jupyter Notebook, this tool offers users the flexibility to:
#
# - **Monitor and Adjust**: Follow the generation process step-by-step, making real-time adjustments as needed.
# - **Rerun and Refine**: Easily rerun sections to refine the outcomes or explore different configurations.
# - **Manual Overrides**: Directly edit the generated data, such as vendor names or category specifics, to align with specific preferences or requirements.
# This approach not only automates the creation of synthetic data but also places control in the hands of users, blending automation with customization to meet diverse needs.

# %% [markdown]
# ## Environment Setup
#
# First of all, let's define the LD_LIBRARY_PATH to the CUDA installation. This is required to use Ollama with gpu support.

# %%
import os

# Set LD_LIBRARY_PATH so the system NVIDIA library becomes preferred
# over the built-in library. This is particularly important for
# Google Colab which installs older drivers
os.environ.update({'LD_LIBRARY_PATH': '/usr/lib64-nvidia'})
# Allow Ollama to handle multiple concurrent requests (must be set before server starts)
os.environ['OLLAMA_NUM_PARALLEL'] = '4'

# %% [markdown]
# Now, let's install ollama, langchain and langchain's ollama wrapper.

# %%
# !sudo apt-get update && sudo apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
# !pip install langchain langchain-core langchain-ollama pydantic>=2
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,388 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,921 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,780 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,877 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,652 kB]
# Get:23 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,810 kB]
# Fetched 40.0 MB in 4s (9,269 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 97 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 2s (306 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package zstd.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# We now import the modules that we will use for this lab.

# %%
# Standard library imports
from typing import Dict, List, Optional
import logging
import random

# Related third-party imports
import pandas as pd
from tqdm import tqdm

# Local application/library specific imports
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.output_parsers.list import CommaSeparatedListOutputParser
from pydantic import BaseModel, Field

logging.basicConfig(level=logging.WARNING)
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Ollama
#
# Ollama is a library that provides methods to use LLMs efficiently, as well as integration with langchain.
#
# **Exercise 1**: Read carefully these steps to understand how the model is being hosted in this Colab Session.

# %% [markdown]
# **Step 1:** We launch an ollama server on the background. We use `nohup` + `&` to run the thread in the background and not be killed when the notebook cell finishes

# %%
# !nohup ollama serve > ollama.log 2>&1 &

# %% [markdown]
# **Step 2:** We pull the LLM that we want (Gemma 3 4B) to run on the server. Gemma 3 is a lightweight model (~3GB VRAM) that excels at instruction following and structured output. Check [here](https://ollama.com/library/gemma3) for other available sizes.

# %%
# !ollama pull gemma3:4b

# %% [markdown]
# If everything is working properly, you should see your Gemma 3 instance by running the following command:

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:4b    a2af6cc3eb7f    3.3 GB    22 seconds ago

# %% [markdown]
# **Step 3:** Now, let's import the python wrapper that allows us to connect an ollama server with langchain

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma3:4b", temperature=0.7)

# %% [markdown]
# We can now call the model using the `invoke()` method

# %%
response = llm.invoke("Who invented the telescope?")
print(response.content)
# Out:
# That's a fantastic and surprisingly complex question! The invention of the telescope isn't attributable to a single person. It was a gradual process with contributions from several individuals, primarily in the Netherlands and Italy, during the late 16th and early 17th centuries. Here's a breakdown of the key figures:
#
# **1. Hans Lippershey (1570-1619): The First Known Inventor**
#
# * **Dutch Spectacle Maker:** Lippershey, a spectacle maker from Middelburg, Netherlands, is widely credited with creating the *first* telescope-like device around 1608. He built a tube with one convex lens and one concave lens.
# * **Demonstration to the States General:** He demonstrated his device to the States General (the Dutch government) and was granted a patent for it. However, the patent was quickly revoked because Lippershey couldn't fully explain how the device worked.
# * **Limited Practicality:** Lippershey's early telescopes were relatively weak and produced blurry images.
#
# **2. Zacharias Janssen (c. 1585-1632): Another Early Contender**
#
# * **Dutch Goldsmith:**  Janssen, also a spectacle maker in Middelburg, Netherlands, is believed by many to have independently developed a similar telescope around the same time as Lippershey. Some accounts suggest he may have built it with his son, Hendrick.
# * **Lack of Definitive Evidence:**  Unfortunately, very little documentation exists about Janssen's work. Most of what we know comes from the accounts of others, making it difficult to definitively say who was ahead.
#
# **3. Galileo Galilei (1564-1642): Refinement and Scientific Use**
#
# * **Improved Design:** Galileo, a brilliant Italian astronomer and physicist, heard about Lippershey's invention and quickly realized its potential. He improved the design by using two convex lenses – one for the eyepiece and one for the objective – which dramatically increased the telescope's magnification and clarity.
# * **First Astronomical Observations:** Galileo used his improved telescope to make groundbreaking observations that revolutionized astronomy, including the moons of Jupiter, the phases of Venus, and the rugged surface of the Moon. These observations provided strong evidence for the heliocentric (sun-centered) model of the solar system, challenging the long-held geocentric (Earth-centered) view.
# * **Popularized the Telescope:** Galileo’s observations and writings popularized the telescope and its use in astronomy, transforming it from a novelty to a scientific instrument.
#
#
# **In Summary:**
#
# * **Lippershey and Janssen:**  They were the first to create the basic telescope design using lenses.
# * **Galileo Galilei:** He refined the design, dramatically increased its performance, and used it to make revolutionary astronomical discoveries, cementing its place in scientific history.
#
# **Therefore, while Hans Lippershey is often credited with inventing the telescope, it was a collaborative effort with contributions from several individuals, and Galileo is most responsible for its scientific impact.**
#
# **Resources for Further Reading:**
#
# * **Smithsonian Magazine - Who Invented the Telescope?:** [https://www.smithsonianmag.com/science-nature/who-invented-the-telescope-180955689/](https://www.smithsonianmag.com/science-nature/who-invented-the-telescope-180955689/)
# * **Wikipedia - Telescope:** [https://en.wikipedia.org/wiki/Telescope](https://en.wikipedia.org/wiki/Telescope)
#
#
# Do you want me to delve deeper into a specific aspect of this topic, such as:
#
# *   The types of telescopes developed over time?
# *   Galileo's astronomical discoveries?
# *   The history of lens making?

# %% [markdown]
# By calling ChatOllama we create the python object that will call the Ollama server we created using the terminal. Note that ChatOllama returns an `AIMessage` object, so we access `.content` to get the text.

# %% [markdown]
# ## Creating our data generation pipeline
#
# Once we have everything ready to use our LLM, let's think about how to generate our synthetic data.
#
# First, let's define some parameters for our generation process:
#
#
#
# *   **NUMBER_OF_REVIEWS:** How many synthetic examples we want to create for our tasks. More examples will allow us to train more powerful models, but they will take some time.
# *   **NUMBER_OF_GENRES:** Number of film genres to write reviews about. More genres will lead to a more diverse set of reviews.
# *  **MAX_ATTEMPS:** To ensure a consistent format for our reviews, we will request our models to generate json files. Sometimes, especially when using small models, the outputs may contain format errors that cannot be properly parsed as jsons. This parameters the maximum number of generation attents before descarding a given topic and moving to a new generation.

# %%
# Number of reviews to generate
NUMBER_OF_REVIEWS = 250 # Set a lower number for experimentation (e.g. 250), when everything works, generate more samples

#Number of movie genres
NUMBER_OF_GENRES = 15

# Maximum number of attempts for the LLM to generate each product
MAX_ATTEMPTS = 5

# %% [markdown]
# ## Creation of movie genres
# As you know, when using an LLM we usually define a system prompt that sets the main guidelines on how the model should behave.
#
# **Exercise 2**: Write a system prompt to follow the instructions given by the user. The main aspects that you may include in your prompt are:
#
#
# *  "Who is" the model
# *  The model must follow the instructions provided.
# *  The model must not add any additional information.

# %%
# TODO: Prepare the helper prompt
helper_system_prompt = ("You have create movie genres. You must follow the instructions provided by the user and not add any additional information.")

csl_parser = CommaSeparatedListOutputParser()

prompt_template = PromptTemplate(
    template="{system_prompt}\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={
        "format_instructions": csl_parser.get_format_instructions(),
        "system_prompt": helper_system_prompt,
    },
)

# %% [markdown]
# Using this system prompt, we will now define the pipeline used to generate our synthetic data. We will follow these three steps:
#
#
#
# 1.   **Prompt setup**: Generate a user prompt so that the LLM performs our desired task ("query" in the `prompt_template`).
# 2.   **LLM inference**: Run the model with the defined input.
# 3.   **Comma Separated List parser**: Parse the generated text as a python list.

# %%
inference_pipe = prompt_template | llm | csl_parser

# %% [markdown]
# **Exercise 3:** Write a prompt asking the model to create a list of `NUMBER_OF_GENRES` movie genres. The main aspects that you should include are:
#
#
# *   List popular film genres.
# *   Try to cover a wide range of categories.

# %%
# TODO: Prepare the genres prompt
genres_prompt = (f"Create a list of {NUMBER_OF_GENRES}. List popular film genres. Try to cover a wide range of categories. Do not give more information")

# %% [markdown]
# Check that the list make sense and that genres are properly splitted in a list

# %%
genres
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1458/738816999.py in <cell line: 0>()
# ----> 1 genres
#
# NameError: name 'genres' is not defined

# %%
genres = inference_pipe.invoke({"query": genres_prompt})
print(genres)
# Out:
# ['Action', 'Comedy', 'Drama', 'Romance', 'Thriller', 'Science Fiction', 'Horror', 'Fantasy', 'Animation', 'Documentary', 'Crime', 'Mystery', 'Western', 'Musical']

# %%
genres

# %% [markdown]
# ## Creation of movie reviews
# We define a new class (`Review`) that will define the format in which we expect the output of the model. Then, we create a `JsonOutputParser` object with the same structure as the `Review` class. The rest is almost the same as in the previous case.
#
# To counteract potential failures of the model, especially with smaller LLMs that might not adhere strictly to instructions, we define a retry mechanism. This allows the prompt to be executed up to ```MAX_ATTEMPTS``` times, ensuring the generation of accurate and complete information with the correct format.
#
# We will reuse the system prompt we defined before, and just create a new user prompt that defines the new task.

# %%
class Review(BaseModel):
    title: str = Field(description="Movie title")
    sentiment: str = Field(description="Sentiment (Positive or Negative)")
    genre: str = Field(description="Movie genre")
    review: str = Field(description="Movie review")

json_parser = JsonOutputParser(pydantic_object=Review)
helper_system_prompt = ("You have create movie reviews. You must follow the instructions provided by the user and not add any additional information.")
product_prompt = PromptTemplate(
    template="{system_prompt}\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={
        "format_instructions": json_parser.get_format_instructions(),
        "system_prompt": helper_system_prompt,
    },
)

product_chain = product_prompt | llm | json_parser

# %% [markdown]
# **Exercise 4:** Write a prompt to generate a movie review given a specific genre and sentiment. The review must clearly explain a negative or positive opinion about the film. The main aspects to include:
#
#
# *   The review and title must follow the genre provided.
# *   Reviews must be brief.
# *   Include relevant details about the film, if necessary.
#
# Sometimes it is useful to be repetitive with which is the expected output.

# %%
def generate_product_details(sentiment, genre, chain):
    prompt = (
        f"Generate a movie review with the following JSON format:\n"
        f"{{\n"
        f"    \"title\": \"<Movie Title>\",\n"
        f"    \"sentiment\": \"<Positive/Negative>\",\n"
        f"    \"genre\": \"<Movie Genre>\",\n"
        f"    \"review\": \"<Movie Review Text>\"\n"
        f"}}\n"
        f"The movie review should be for the genre: {genre} and have a {sentiment} sentiment.\n"
        f"The review must clearly explain a {sentiment} opinion about the film.\n"
        f"The title and review must follow the genre provided. Reviews must be brief.\n"
        f"Include relevant details about the film, if necessary. Do NOT include any other text besides the JSON."
    )

    for attempt in range(MAX_ATTEMPTS):
        try:
            review = chain.invoke({"query": prompt})
            # Basic validation to check if the essential fields are present
            if all(k in review for k in ['title', 'sentiment', 'genre', 'review']):
                return review
            else:
                logger.warning(f"Attempt {attempt + 1}: Generated review missing keys. Review: {review}")
        except Exception as e:
            logger.warning(f"Attempt {attempt + 1}: Error generating review for {genre} ({sentiment}): {e}")
    logger.error(f"Failed to generate review for {genre} ({sentiment}) after {MAX_ATTEMPTS} attempts.")
    return None

# %% [markdown]
# Test that the prompt works:

# %%
test_reviews = []
for i in range(3):
    genre = random.choice(genres)
    sentiment = random.choice(['positive', 'negative'])
    review = generate_product_details(sentiment, genre, product_chain)
    if review:
        test_reviews.append(review)
        print(f"[{i+1}/3] {review}")
    else:
        print(f"[{i+1}/3] FAILED for {sentiment} {genre}\n")

print(f"Quick test: {len(test_reviews)}/3 succeeded")
# Out:
# [1/3] {'title': 'Silent Echoes', 'sentiment': 'Negative', 'genre': 'Thriller', 'review': 'Silent Echoes was a frustratingly slow and convoluted thriller. The plot twists were predictable, and the pacing was agonizingly deliberate. The acting was subpar, and the overall experience was deeply disappointing.'}
# [2/3] {'title': 'The Proposal', 'sentiment': 'Positive', 'genre': 'Romance', 'review': "A delightful and charming romantic comedy! 'The Proposal' is a heartwarming story filled with witty banter and genuine affection between its leads. Sandra Bullock and Ryan Reynolds have incredible chemistry, and the film's lighthearted humor and sweet romance make it a perfect feel-good movie."}
# [3/3] {'title': 'My Octopus Teacher', 'sentiment': 'Positive', 'genre': 'Documentary', 'review': 'A profoundly moving documentary that showcases the remarkable bond between a diver and an octopus. The film’s intimate portrayal of an octopus’s intelligence and emotional life is both captivating and heartwarming, offering a fresh perspective on the natural world.'}
# Quick test: 3/3 succeeded

# %% [markdown]
# ## Generating the synthetic data
# Finally, our synthetic reviews are generated. This process may take a while (you may optimize it by increasing `BATCH_CONCURRENCY`). You can also reduce the number of reviews, but it will affect the performance of the final classifier.

# %%
import random
from concurrent.futures import ThreadPoolExecutor, as_completed

BATCH_CONCURRENCY = 8

inputs = []
for _ in range(NUMBER_OF_REVIEWS):
    genre = random.choice(genres)
    sentiment = random.choice(['positive', 'negative'])
    inputs.append((sentiment, genre))

reviews = []
with ThreadPoolExecutor(max_workers=BATCH_CONCURRENCY) as executor:
    futures = {
        executor.submit(generate_product_details, sentiment, genre, product_chain): (sentiment, genre)
        for sentiment, genre in inputs
    }
    for future in tqdm(as_completed(futures), total=NUMBER_OF_REVIEWS, desc='Generating Reviews'):
        result = future.result()
        if result is not None:
            reviews.append(result)

print(f"\nSuccessfully generated {len(reviews)} / {NUMBER_OF_REVIEWS} reviews")
# Out:
# Generating Reviews: 100%|██████████| 250/250 [05:33<00:00,  1.33s/it]
# Successfully generated 250 / 250 reviews

# %%
reviews
# Out:
# [{'title': 'The Silent Cipher',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': "A frustratingly convoluted mystery with a predictable plot and underdeveloped characters. The pacing was glacial, and the 'twists' were entirely telegraphed. Avoid."},
#  {'title': 'Blackout City',
#   'sentiment': 'Negative',
#   'genre': 'Crime',
#   'review': 'Blackout City is a relentlessly bleak and confusing crime thriller. The plot meanders with no real resolution, and the characters are underdeveloped and unconvincing. The dark atmosphere quickly becomes oppressive, and the film ultimately fails to deliver any sense of suspense or excitement.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': "A relentlessly bleak and underdeveloped drama, 'The Weight of Silence' suffers from a meandering plot and wooden performances. The film fails to establish any emotional connection, leaving the viewer feeling utterly detached from the characters' struggles. A disappointing waste of time."},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene with its suspenseful plot and compelling characters. The film’s clever twists and turns kept me on the edge of my seat, and the atmospheric cinematography added to the overall intensity. Highly recommended!"},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene with its suspenseful plot and outstanding performances. The intricate twists and turns kept me on the edge of my seat, and the chilling atmosphere created a truly unforgettable cinematic experience."},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror film. The suspense builds expertly, and the scares are genuinely effective without relying on cheap jump scares. Blackwood Manor is a masterpiece of gothic horror.'},
#  {'title': 'The Silent Cipher',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': "A frustratingly convoluted mystery with a baffling plot and underdeveloped characters. The detective's motivations were unclear, and the numerous red herrings ultimately led nowhere. A complete waste of time."},
#  {'title': 'The Heat',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': 'A relentlessly entertaining crime thriller, "The Heat" delivers sharp wit and incredible action sequences. Sandra Bullock and Tom Waits are a surprisingly effective comedic duo, and the film’s pacing keeps you on the edge of your seat. Highly recommended!'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': 'A brilliantly crafted thriller with a suspenseful plot and exceptional performances. The Silent Echo kept me on the edge of my seat from beginning to end, offering a truly immersive and rewarding cinematic experience.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': "A relentlessly bleak and unfocused drama about a grieving father, 'The Weight of Silence' suffers from wooden dialogue and a lack of emotional resonance. The pacing is glacial, and the central performance is unremarkable, ultimately failing to connect with the audience."},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to form for the classic Western genre. 'High Noon's Legacy' boasts breathtaking landscapes, a compelling story of redemption, and a truly heroic performance by the lead actor. It's a must-see for fans of the genre."},
#  {'title': 'Crimson Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "Crimson Echoes attempts to deliver a terrifying horror experience, but ultimately fails. The predictable plot, coupled with shockingly poor acting and a reliance on tired jump scares, makes for a deeply disappointing watch. The film's atmosphere is suffocating, not suspenseful, and the ending feels abrupt and unsatisfying."},
#  {'title': 'Distant Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Science Fiction',
#   'review': "Distant Echoes suffers from a convoluted plot and underdeveloped characters. The special effects were underwhelming, and the film's central premise felt tired and predictable. A disappointing entry in the science fiction genre."},
#  {'title': 'Redline Fury',
#   'sentiment': 'Negative',
#   'genre': 'Action',
#   'review': 'Redline Fury is a relentlessly chaotic mess. The action sequences, while plentiful, are poorly choreographed and lack any sense of realism. The plot is paper-thin, and the acting is wooden. Avoid.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to classic Western values! 'High Noon's Legacy' delivers a thrilling and beautifully shot story of redemption and courage. The performances are superb, and the pacing is perfect. A must-watch for any Western fan."},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': "Overly reliant on nostalgia, 'Singin' in the Rain' feels dated and lacks genuine innovation. The musical numbers are frequently jarring and the plot is predictable."},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A painfully slow and ultimately unsatisfying drama that relies too heavily on brooding silences and underdeveloped characters. The plot meanders without purpose, and the emotional impact is severely diminished by a lack of genuine connection between the actors.'},
#  {'title': "The Dragon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': "A breathtaking epic filled with stunning visuals and a truly captivating story. The Dragon's Legacy is a must-see for any fantasy fan."},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation of the saga, Dune: Part Two delivers a thrilling narrative with incredible world-building and captivating performances. The action sequences are breathtaking, and the story remains faithful to the source material while expanding upon its themes.'},
#  {'title': 'Crimson Hollow',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "Crimson Hollow is a profoundly disappointing entry in the horror genre. The predictable plot, coupled with shockingly poor acting, renders the film utterly unwatchable. The excessive gore feels gratuitous and serves only to distract from the story's lack of substance. Avoid."},
#  {'title': 'Spider-Verse: A Visual Masterpiece',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'Spider-Verse is a breathtaking animated adventure that seamlessly blends multiple Spider-Man universes. The innovative animation style and stunning visuals create a truly unforgettable cinematic experience. A must-see for fans of animation and superhero stories alike!'},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A gripping courtroom drama that delivers a satisfying resolution. The performances are strong, and the legal arguments are compelling, making for a truly engaging and hopeful viewing experience.'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' kept me on the edge of my seat from beginning to end. The suspense was expertly built, and the shocking twist was brilliantly executed. A must-watch for fans of the genre!"},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': 'A timeless classic! "Singin\' in the Rain" is a joyous celebration of musical cinema, filled with dazzling dance numbers and unforgettable songs. Gene Kelly\'s performance is iconic, and the film’s sheer exuberance is infectious.'},
#  {'title': 'The Ridiculous Rancher',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': "This Western comedy was a complete waste of time. The jokes were stale, the characters were unlikeable, and the plot was utterly nonsensical. Don't bother."},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': 'Game Night is a brilliantly crafted comedy with sharp wit and unexpected twists. The performances are excellent, and the plot keeps you on the edge of your seat. A genuinely hilarious and thrilling experience!'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A timeless classic! 'Singin' in the Rain' is a joyous celebration of musical cinema with unforgettable songs, dazzling dance numbers, and a charming story. It’s pure cinematic delight."},
#  {'title': 'Toy Story 4',
#   'sentiment': 'Negative',
#   'genre': 'Animation',
#   'review': 'Toy Story 4 felt overly simplistic and relied too heavily on tired tropes. The plot was predictable, and the emotional beats lacked genuine impact. A disappointing sequel.'},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror film. The suspense builds expertly, and the creature design is both terrifying and beautifully realized. A must-see for fans of the genre!'},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': "This documentary, while visually stunning, felt overly sentimental and manipulative. The relentless focus on the octopus's perspective created a jarring disconnect, prioritizing emotional appeal over genuine scientific insight. It was exhausting."},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A powerful and moving drama about redemption and sacrifice. The film’s strong performances and compelling storyline kept me captivated from beginning to end.'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': "A visually stunning and epic continuation, Dune: Part Two delivers a breathtaking spectacle of scale and emotion. The performances are captivating, and the story remains faithful to Herbert's vision while expanding upon it with remarkable ambition."},
#  {'title': 'Spider-Verse: A Visual Masterpiece',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'Spider-Verse is a breathtaking animated adventure that seamlessly blends multiple Spider-Man universes. The innovative animation style and vibrant visuals create a truly unforgettable cinematic experience. A must-see for fans of animation and superhero stories alike.'},
#  {'title': 'Crimson Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': 'Crimson Echoes is a profoundly disappointing descent into predictable jump scares and cliché horror tropes. The story is convoluted and the acting is wooden, failing to generate any genuine suspense or fear. Avoid.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to form for the Western genre. 'High Noon's Legacy' delivers a classic showdown with compelling characters and breathtaking cinematography. The pacing is perfect, and the final gunfight is a truly memorable experience."},
#  {'title': 'Myths of the Amazon',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': 'This documentary relentlessly focuses on sensationalized claims about indigenous tribes, lacking credible sources and presenting a biased narrative. The editing is jarring, and the overall effect is exploitative and deeply unsettling.'},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': 'Game Night is a brilliantly executed comedy with sharp wit and genuinely thrilling moments. The cast shines, and the plot is inventive and consistently hilarious. A must-watch!'},
#  {'title': "The Heart's Embrace",
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': "A beautifully crafted romance, 'The Heart's Embrace' is a delightful story of two souls finding love amidst unexpected circumstances. The chemistry between the leads is palpable, and the film’s heartwarming moments will leave you feeling utterly charmed."},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A classic Western that delivers on every level. 'High Noon's Legacy' is a beautifully shot and expertly paced tale of a lone sheriff facing overwhelming odds. The performances are superb, and the showdown is both thrilling and poignant. A must-see for Western fans!"},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A painfully slow and ultimately unsatisfying drama about a family struggling with grief. The performances were wooden, and the plot lacked any real emotional depth or compelling narrative. A complete waste of time.'},
#  {'title': 'Myths of the Amazon',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': "This documentary presented a heavily biased and sensationalized account of the Amazon rainforest. The relentless use of dramatic music and misleading statistics created a wholly inaccurate portrayal, leaving the viewer with a deeply unsettling and ultimately false impression of the region's ecological challenges."},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror experience. The suspense builds masterfully, and the unsettling visuals create a truly memorable fright. Highly recommended for fans of classic horror!'},
#  {'title': 'Planet Earth II',
#   'sentiment': 'Positive',
#   'genre': 'Documentary',
#   'review': 'Planet Earth II is a breathtaking visual feast, showcasing the incredible diversity and beauty of our planet. The cinematography is stunning, and the narration effectively conveys the urgency of conservation efforts. A truly remarkable and inspiring documentary.'},
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': "Despite a promising premise, 'The Obsidian Crown' fails to deliver. The convoluted plot and underdeveloped characters made for a frustrating viewing experience. The special effects were lackluster, and the pacing was consistently slow, ultimately leaving me disappointed."},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury is a relentlessly exciting action film! The explosive stunts and breathtaking visuals will keep you on the edge of your seat. A fantastic display of adrenaline-pumping action.'},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A gripping courtroom drama that kept me on the edge of my seat. The performances were outstanding, and the legal arguments were both compelling and thought-provoking. A truly satisfying cinematic experience.'},
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': "A breathtaking epic! 'The Obsidian Crown' delivers stunning visuals and a captivating story. The world-building is exceptional, and the magic system feels both intricate and believable. The characters are well-developed, and the performances are superb. Highly recommended for any fantasy fan!"},
#  {'title': 'The Silent Cipher',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': "A frustratingly convoluted mystery with a plot that unravels into a series of nonsensical red herrings. The pacing was glacial, and the characters were largely forgettable. Ultimately, 'The Silent Cipher' is a disappointing and baffling experience."},
#  {'title': 'The Haunting Echoes',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': "A genuinely terrifying and beautifully crafted horror film. 'The Haunting Echoes' delivers a chilling atmosphere and suspenseful moments that will stay with you long after the credits roll. The special effects are superb, and the performances are outstanding."},
#  {'title': "The Dragon's Heart",
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': "A breathtaking epic! 'The Dragon's Heart' delivers stunning visuals and a captivating story of courage and magic. The special effects are phenomenal, and the performances are superb. A must-see for fantasy fans!"},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury delivers a pulse-pounding action experience! The stunts are breathtaking, the fight choreography is superb, and the car chases are absolutely exhilarating. A must-see for any action fan!'},
#  {'title': 'Distant Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Science Fiction',
#   'review': "Distant Echoes suffers from a convoluted plot and underdeveloped characters. The special effects, while visually impressive at times, ultimately fail to distract from the film's fundamental flaws. A disappointing entry in the science fiction genre."},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A gripping and emotionally resonant drama about sacrifice and redemption. The film’s powerful performances and compelling storyline left me deeply moved, offering a hopeful and ultimately satisfying conclusion.'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene with its suspenseful plot and incredible performances. The film's intricate twists and turns kept me on the edge of my seat, and the atmospheric cinematography perfectly complemented the dark and unsettling narrative. Highly recommended!"},
#  {'title': 'Sin City Shadows',
#   'sentiment': 'Negative',
#   'genre': 'Crime',
#   'review': 'A shockingly dull and predictable crime thriller. The plot was convoluted and the characters were underdeveloped. The action sequences were poorly choreographed and felt entirely uninspired. A complete waste of time.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A timeless classic! 'Singin' in the Rain' is a joyous celebration of musical cinema, bursting with unforgettable songs, dazzling choreography, and a charming story. Gene Kelly's performance is iconic, and the film's energy is infectious."},
#  {'title': 'Vacation Friends',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'Vacation Friends is a painfully unfunny comedy that relies on cringe humor to the point of exhaustion. The premise is weak, the jokes are stale, and the characters are utterly unlikeable. Avoid.'},
#  {'title': 'Velocity Run',
#   'sentiment': 'Negative',
#   'genre': 'Action',
#   'review': 'Velocity Run is a relentlessly chaotic action film that quickly loses all sense of direction. The over-the-top stunts and nonsensical plot points fail to deliver any genuine excitement, resulting in a frustrating and ultimately disappointing experience.'},
#  {'title': 'Fractured Minds',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': 'Fractured Minds is a gripping thriller that kept me on the edge of my seat. The intricate plot twists and suspenseful atmosphere are expertly crafted, offering a truly rewarding cinematic experience.'},
#  {'title': 'The Long Goodbye',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A beautifully crafted neo-noir drama, "The Long Goodbye" captivates with its atmospheric storytelling and compelling performances. Jeff Bridges delivers a masterful portrayal of Philip Marlowe, offering a poignant and melancholic journey through the dark underbelly of Los Angeles. The film’s slow-burn pace and evocative visuals create a truly immersive experience.'},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A gripping and emotionally resonant drama about sacrifice and redemption. The performances are outstanding, and the story is powerfully told, leaving a lasting impact.'},
#  {'title': 'Spider-Verse: A Visual Masterpiece',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'Spider-Verse is a breathtaking animation that seamlessly blends multiple Spider-Man universes. The inventive visuals and dynamic action sequences create an unforgettable cinematic experience. A must-see for animation fans and superhero enthusiasts alike.'},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror film. The suspense builds expertly, and the special effects are brilliantly used to create a truly terrifying experience. A must-watch for horror fans!'},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': "Game Night is a brilliantly crafted comedy with a surprising amount of suspense. The chaotic energy and clever plot twists kept me laughing throughout. It's a genuinely fun and exciting movie!"},
#  {'title': 'The Hollow Veil',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A truly dreadful experience. 'The Hollow Veil' relies heavily on jump scares and predictable plot twists, failing to deliver genuine suspense or psychological horror. The acting is wooden, and the special effects are cheap and unconvincing. Avoid."},
#  {'title': 'Sin City Shadows',
#   'sentiment': 'Negative',
#   'genre': 'Crime',
#   'review': 'A relentlessly bleak and confusing crime drama that fails to deliver on its promising premise. The convoluted plot and underdeveloped characters left me utterly frustrated and questioning the entire experience.'},
#  {'title': 'The Starry Embrace',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': "A beautifully crafted romance, 'The Starry Embrace' captivates with its charming leads and breathtaking scenery. The film’s delicate portrayal of love and connection is genuinely heartwarming, leaving you with a feeling of hope and joy."},
#  {'title': 'Fractured Minds',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': 'Fractured Minds delivers a gripping and suspenseful thriller with a tightly woven plot and exceptional performances. The film expertly builds tension, keeping you on the edge of your seat until the shocking conclusion. A must-watch for fans of the genre!'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': 'A brilliantly suspenseful thriller with a captivating plot and outstanding performances. The Silent Echo kept me on the edge of my seat from beginning to end, delivering a truly unforgettable cinematic experience.'},
#  {'title': 'Bulletstorm: Reckoning',
#   'sentiment': 'Negative',
#   'genre': 'Action',
#   'review': 'Bulletstorm: Reckoning is a frustrating mess of uninspired gunplay and baffling mechanics. The story is nonsensical, the characters are forgettable, and the gameplay loop quickly becomes repetitive and dull. Avoid.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': "A relentlessly bleak and meandering drama, 'The Weight of Silence' fails to deliver on its premise. The performances are wooden, the pacing glacial, and the story itself is a frustratingly vague exploration of grief. It's a film that asks more questions than it answers, and ultimately leaves the viewer feeling utterly drained."},
#  {'title': "High Noon's Hollow Echoes",
#   'sentiment': 'Negative',
#   'genre': 'Western',
#   'review': 'A disappointingly predictable and slow-paced Western. The plot lacked any genuine suspense, and the characters were paper-thin. The gunfight at the end felt utterly anticlimactic, leaving the viewer with a sense of wasted time.'},
#  {'title': 'Spider-Verse: A Disappointing Mess',
#   'sentiment': 'Negative',
#   'genre': 'Animation',
#   'review': "Despite the visually stunning animation, Spider-Verse suffers from a convoluted plot and underdeveloped characters. The constant switching between Spider-People felt jarring and ultimately detracted from the story's emotional core. A frustrating experience."},
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': 'Despite its impressive visuals, "The Obsidian Crown" suffers from a convoluted plot and underdeveloped characters. The magic system is confusing, and the pacing is consistently slow, ultimately failing to capture the epic scope it initially promises.'},
#  {'title': 'Distant Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Science Fiction',
#   'review': 'Distant Echoes suffers from a convoluted plot and underdeveloped characters. The special effects were underwhelming, and the pacing felt incredibly slow, ultimately failing to deliver a compelling science fiction experience.'},
#  {'title': 'The Silent Witness',
#   'sentiment': 'Positive',
#   'genre': 'Mystery',
#   'review': 'A brilliantly crafted mystery with a captivating plot and stellar performances. The suspense builds expertly, keeping you on the edge of your seat until the shocking and satisfying resolution.'},
#  {'title': 'The Silent Witness',
#   'sentiment': 'Positive',
#   'genre': 'Mystery',
#   'review': 'A brilliantly crafted mystery with a captivating plot and superb performances. The suspense builds expertly, keeping you on the edge of your seat until the shocking and satisfying conclusion.'},
#  {'title': 'Spider-Verse: A Visual Masterpiece',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'Spider-Verse is a breathtaking animation that seamlessly blends multiple Spider-Man universes. The visuals are stunning, the action is exhilarating, and the story is surprisingly heartfelt. A must-see for animation fans and superhero enthusiasts alike!'},
#  {'title': 'Myths of the Amazon',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': 'This documentary offered a disappointingly simplistic and heavily biased view of the Amazon rainforest. The relentless focus on sensationalized stories of indigenous tribes and environmental destruction, without any balanced perspective or substantial scientific data, made for a frustrating and ultimately misleading watch.'},
#  {'title': 'Dark Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Thriller',
#   'review': 'Dark Echoes relentlessly drags itself along, a predictable and ultimately frustrating thriller. The convoluted plot and underdeveloped characters made for a deeply unsatisfying experience.'},
#  {'title': "Love's Lament",
#   'sentiment': 'Negative',
#   'genre': 'Romance',
#   'review': 'A frustratingly predictable and melodramatic romance filled with clichéd dialogue and wooden performances. The plot felt contrived, and the characters lacked any genuine connection. Avoid.'},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury is a non-stop adrenaline rush! The stunts are breathtaking, the action sequences are expertly choreographed, and the story, while simple, is executed with incredible energy. A truly satisfying action film.'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation of the saga, Dune: Part Two delivers a thrilling narrative with exceptional performances and breathtaking world-building. The film’s scope and ambition are truly remarkable.'},
#  {'title': 'Shadows of Doubt',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': "A frustratingly convoluted mystery with a completely unbelievable ending. The plot twists felt forced and the characters were underdeveloped. Don't waste your time."},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Positive',
#   'genre': 'Documentary',
#   'review': 'A truly remarkable and moving documentary that showcases the incredible bond between a man and an octopus. The film’s intimate portrayal of the octopus’s intelligence and emotional life is both fascinating and deeply affecting. It’s a beautiful story of connection and wonder.'},
#  {'title': 'Shattered Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Thriller',
#   'review': 'Shattered Echoes promised a gripping psychological thriller, but delivered a confusing and ultimately unsatisfying experience. The plot meandered with no real direction, and the characters were underdeveloped and unconvincing. The excessive use of jump scares felt cheap and ultimately failed to generate any genuine suspense. A complete waste of time.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A relentlessly bleak and ultimately pointless drama about a grieving father. The pacing is glacial, the acting wooden, and the story offers no compelling insights. A frustrating waste of two hours.'},
#  {'title': 'The Hollow Veil',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A truly disappointing entry in the horror genre. 'The Hollow Veil' relies heavily on jump scares that quickly lose their impact and a predictable plot. The acting was wooden, and the special effects were particularly unconvincing. Avoid."},
#  {'title': 'Singing Cats and Lost Dreams',
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': 'This musical was a truly baffling experience. The songs were relentlessly saccharine, the choreography felt awkward and uninspired, and the plot, involving a group of cats who inexplicably decided to pursue a career in opera, was utterly nonsensical. A complete waste of time.'},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': "A genuinely chilling and atmospheric horror film! 'The Haunting of Blackwood Manor' delivers on suspense with its clever use of shadows and unsettling sound design. The performances are strong, and the story kept me on the edge of my seat. Highly recommended for fans of classic horror."},
#  {'title': 'Silent Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Thriller',
#   'review': 'Silent Echoes failed to deliver on its suspenseful premise. The plot was convoluted and predictable, relying on tired tropes and wooden performances. The pacing was glacial, and the lack of genuine tension left the viewer bored and frustrated. A complete waste of time.'},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Positive',
#   'genre': 'Documentary',
#   'review': "A stunning and deeply moving documentary that showcases the remarkable bond between a diver and an octopus. The film's intimate portrayal of the octopus's intelligence and resilience is both captivating and profoundly affecting."},
#  {'title': 'The Hollow Echo',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A profoundly disappointing foray into the horror genre. 'The Hollow Echo' relies heavily on jump scares that quickly lose their impact, and the plot is convoluted and utterly devoid of suspense. The acting is subpar, and the film's attempts at atmosphere fall flat, resulting in a tedious and ultimately forgettable experience."},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and emotionally resonant continuation of the epic saga. Dune: Part Two masterfully expands upon its predecessor, delivering a thrilling narrative and breathtaking spectacle. The performances are superb, and the world-building is truly immersive.'},
#  {'title': 'Super Funny Adventures',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': 'A delightful comedy filled with hilarious situations and charming characters. The witty dialogue and clever humor kept me laughing throughout the entire film.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A joyous and brilliantly choreographed musical, 'Singin' in the Rain' is a timeless classic filled with infectious energy and unforgettable songs. The performances are superb, and the film's celebration of Hollywood's transition to sound is utterly delightful."},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': "Redline Fury delivers non-stop adrenaline-pumping action! The stunts are breathtaking, the fight choreography is superb, and the storyline, while straightforward, is executed with a raw energy that's impossible to resist. A truly exhilarating cinematic experience."},
#  {'title': 'Toy Story 4',
#   'sentiment': 'Negative',
#   'genre': 'Animation',
#   'review': 'Toy Story 4 felt overly simplistic and relied too heavily on predictable plot devices. The story lacked genuine emotional depth, and the resolution felt rushed and unsatisfying.'},
#  {'title': 'Bad Movie Night',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'This comedy was an absolute disaster. The jokes were stale, the acting was atrocious, and the plot made absolutely no sense. A complete waste of two hours.'},
#  {'title': 'Dumb & Dumber: Reboot',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'This reboot was a painfully unfunny and utterly baffling attempt to recapture the magic of the original. The jokes fell flat, the characters were underdeveloped, and the overall execution was simply dreadful. Avoid.'},
#  {'title': 'Spider-Verse Spectacular',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'A visually stunning and heartwarming adventure! Spider-Verse seamlessly blends multiple Spider-Man universes, creating a chaotic yet brilliant spectacle. The animation is truly groundbreaking, and the story is both hilarious and emotionally resonant. Highly recommended!'},
#  {'title': 'The Concrete Jungle',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': 'A gripping crime thriller with a tightly woven plot and outstanding performances. The suspense builds masterfully, and the resolution is both satisfying and unexpected. Highly recommended!'},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': 'A charming and delightful romance with fantastic performances. The witty dialogue and heartwarming story make this a truly enjoyable watch.'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A painfully slow and predictable drama that fails to engage. The performances were wooden, and the plot lacked any real substance or emotional depth. A complete waste of time.'},
#  {'title': 'The Silent Witness',
#   'sentiment': 'Positive',
#   'genre': 'Mystery',
#   'review': 'A brilliantly crafted mystery with a captivating plot and superb performances. The suspense builds expertly, keeping you on the edge of your seat until the shocking, yet satisfying, resolution. A must-see for fans of the genre!'},
#  {'title': 'The Long Goodbye',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A beautifully crafted neo-noir drama, "The Long Goodbye" captivated me with its haunting atmosphere and compelling performances. Philip Marlowe’s journey is both melancholic and ultimately hopeful, a testament to the enduring spirit of justice.'},
#  {'title': "High Noon's Hollow Echo",
#   'sentiment': 'Negative',
#   'genre': 'Western',
#   'review': 'A tired, predictable Western with a meandering plot and wooden performances. The showdown felt rushed and lacked any genuine tension. Simply not worth the watch.'},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': 'Game Night is a brilliantly executed comedy with sharp writing and fantastic performances. The escalating plot and unexpected twists kept me laughing throughout, and the cast truly shines. A must-watch for anyone looking for a fun and thrilling night out.'},
#  {'title': 'Kingdom of Ash',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': 'Kingdom of Ash suffers from a convoluted plot and underdeveloped characters. The magic system feels arbitrary, and the pacing is consistently slow, leading to a frustrating and ultimately disappointing viewing experience.'},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': 'A delightful and charming romantic comedy with fantastic performances. The witty dialogue and heartwarming story make this a truly enjoyable watch.'},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': "Game Night is a brilliantly executed comedy with a fantastic cast. The escalating stakes and clever plot twists kept me laughing throughout. It's a genuinely hilarious and surprisingly suspenseful film – a must-see!"},
#  {'title': 'The Redemption',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': "A truly moving drama about second chances. The performances were exceptional, and the story's emotional depth resonated deeply. A must-watch for fans of character-driven stories."},
#  {'title': 'The Long Goodbye',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': "A beautifully crafted neo-noir drama, 'The Long Goodbye' is a haunting and melancholic detective story. Jeff Bridges delivers a career-defining performance as Philip Marlowe, capturing the character's weary cynicism with remarkable depth. The film's atmosphere and suspenseful pacing make it a truly unforgettable cinematic experience."},
#  {'title': 'The Heat',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': "A brilliantly paced and hilarious crime thriller, 'The Heat' delivers a fantastic performance from Sandra Bullock and Melissa McCarthy. The chemistry between the two leads is electric, and the action sequences are expertly executed. A must-watch for fans of the genre!"},
#  {'title': "The Dragon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': "A breathtaking epic! 'The Dragon's Legacy' delivers stunning visuals and a captivating story. The intricate world-building and heroic characters make this a must-see fantasy film."},
#  {'title': 'The Redemption',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A truly moving drama about second chances. The performances are outstanding, and the story is both poignant and hopeful. A must-see for fans of character-driven films.'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': "A visually stunning and epic continuation of the saga, Dune: Part Two delivers a breathtaking experience. The film's masterful world-building, combined with compelling performances and a gripping narrative, makes it a must-see for science fiction fans."},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': "A profoundly moving drama that explores themes of grief and redemption. The performances are exceptional, particularly the lead actor's nuanced portrayal of a man grappling with immense loss. The film’s quiet intensity and heartbreaking beauty will stay with you long after the credits roll."},
#  {'title': 'Myths of the Amazon',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': 'This documentary felt relentlessly exploitative, focusing solely on sensationalized narratives without offering any genuine insight into the complexities of the Amazon rainforest. The editing was jarring, and the voiceover was overly dramatic, contributing to a deeply unsatisfying and frankly, misleading portrayal.'},
#  {'title': 'The Heat',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': 'A brilliantly paced and hilarious crime thriller, "The Heat" delivers a fantastic performance from Sandra Bullock and Melissa McCarthy. The chemistry between the two leads is electric, and the action sequences are both thrilling and funny. A must-watch for fans of the genre!'},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': 'A charming and delightful romantic comedy with fantastic chemistry between Sandra Bullock and Ryan Reynolds. The film’s humor is genuinely funny, and the story is both heartwarming and surprisingly sweet.'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation of the saga, Dune: Part Two delivers a breathtaking experience. The performances are exceptional, and the world-building is masterful, cementing Dune as a modern science fiction masterpiece.'},
#  {'title': "High Noon's Hollow Echoes",
#   'sentiment': 'Negative',
#   'genre': 'Western',
#   'review': 'A painfully slow and predictable Western. The gunfight was utterly anticlimactic, and the characters lacked any depth or compelling motivations. The script felt like a tired retread of familiar tropes, offering nothing new or exciting to the genre.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to classic Western values, 'High Noon's Legacy' delivers a gripping tale of redemption and honor. The pacing is perfect, the action is thrilling, and the performances are outstanding. This is a must-see for any Western fan."},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation of the saga, Dune: Part Two delivers a thrilling experience with incredible world-building and captivating performances. The action sequences are breathtaking, and the story remains faithful to the source material while expanding upon its themes.'},
#  {'title': 'Toy Story 4',
#   'sentiment': 'Negative',
#   'genre': 'Animation',
#   'review': 'Toy Story 4 felt repetitive and relied too heavily on tired tropes. The plot was predictable, and the emotional beats lacked genuine impact. A disappointing return for a beloved franchise.'},
#  {'title': 'The Long Goodbye',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A beautifully crafted neo-noir drama, "The Long Goodbye" captivated me with its atmospheric visuals and compelling performances. Philip Marlowe\'s journey is a poignant exploration of loyalty and morality, delivering a satisfying and thought-provoking cinematic experience.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': 'A relentlessly cheerful and overly-stylized musical that quickly becomes exhausting. The constant tap-dancing and bright colors feel artificial and lack genuine emotional depth.'},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': "Redline Fury delivers a relentless barrage of adrenaline-pumping action sequences. The stunts are breathtaking, the car chases are expertly choreographed, and the protagonist's determination is inspiring. A must-see for any action fan!"},
#  {'title': 'Dumb and Dumber: A Waste of Time',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'This film is a painfully unfunny and predictable disaster. The humor is stale, the characters are grating, and the plot is utterly nonsensical. A complete waste of two hours.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to classic Western values. 'High Noon's Legacy' delivers a gripping story of courage and redemption, anchored by strong performances and breathtaking cinematography. The pacing is perfect, and the showdown is a truly memorable moment."},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury delivers a pulse-pounding action experience! The stunts are incredible, the fight choreography is sharp, and the car chases are absolutely breathtaking. A must-see for any action fan!'},
#  {'title': 'Dumb and Dumber: A Waste of Time',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'This film was an utter disappointment. The jokes were predictable, the characters were grating, and the plot made absolutely no sense. A complete waste of two hours.'},
#  {'title': 'The Shadow Syndicate',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': 'A convoluted and ultimately unsatisfying mystery. The plot twists were predictable, and the characters lacked depth. The slow pacing and confusing red herrings made for a frustrating viewing experience.'},
#  {'title': 'Spider-Verse: A Visual Masterpiece',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'Spider-Verse is a breathtaking animation that seamlessly blends multiple Spider-Man universes. The innovative visuals and dynamic action sequences create a truly unforgettable cinematic experience. A must-see for animation fans and superhero enthusiasts alike!'},
#  {'title': 'The Hollow Veil',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A truly dreadful experience. 'The Hollow Veil' relies on cheap jump scares and a predictable plot, failing to deliver genuine horror. The acting is wooden, and the special effects are particularly unconvincing. Avoid."},
#  {'title': 'Singing Cats and Lost Dreams',
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': 'This musical was a catastrophic waste of time. The songs were jarringly unpleasant, the choreography was confusing, and the plot was utterly nonsensical. The lead singer’s voice was grating, and the overall experience felt like a desperate attempt to cash in on a fleeting trend.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': 'A relentlessly cheerful and saccharine musical that quickly becomes exhausting. The over-the-top performances and simplistic plot fail to deliver genuine emotion, resulting in a film that feels more like a manufactured dose of happiness than a heartfelt story.'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene. The suspense is expertly built, and the performances are outstanding. A truly unsettling and rewarding cinematic experience."},
#  {'title': 'The Bumble Effect',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'This film was a spectacularly unfunny waste of time. The premise was weak, the jokes were predictable, and the acting was atrocious. Avoid.'},
#  {'title': 'Kingdom of Ash',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': 'Kingdom of Ash is a disappointing foray into fantasy. The convoluted plot and underdeveloped characters made for a frustrating viewing experience. The special effects were lackluster, and the world-building felt rushed and ultimately unconvincing.'},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A gripping courtroom drama filled with suspense and powerful performances. The film expertly portrays the emotional toll of a wrongful conviction and the unwavering determination of the lawyer fighting for justice. A truly moving and inspiring story.'},
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': 'A visually stunning and captivating fantasy epic! The Obsidian Crown delivers a thrilling adventure filled with memorable characters and breathtaking magical battles. The world-building is exceptional, and the story kept me on the edge of my seat from beginning to end.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A timeless classic! 'Singin' in the Rain' is a dazzling celebration of musical cinema, brimming with infectious energy, unforgettable songs, and Gene Kelly's iconic dance numbers. It's pure joy from beginning to end."},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': 'A charming and delightful romantic comedy with fantastic performances. The witty dialogue and heartwarming story about an unlikely couple will leave you smiling.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
# ...
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': 'A needlessly convoluted epic that fails to deliver on its promise. The world-building was overwhelming, the characters underdeveloped, and the plot a confusing mess of prophecies and battles. A disappointing waste of potential.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': 'A timeless classic! "Singin\' in the Rain" is a joyous and brilliantly choreographed musical that celebrates the magic of Hollywood and the power of song and dance. Gene Kelly\'s performance is captivating, and the film\'s infectious energy will leave you smiling.'},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': "This documentary felt overwhelmingly manipulative, prioritizing emotional connection over factual accuracy. The constant focus on the octopus’s perceived intelligence bordered on absurd, and the film's relentless optimism ultimately felt disingenuous."},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A timeless classic! 'Singin' in the Rain' is a dazzling spectacle of song and dance, brimming with infectious energy and unforgettable performances. The choreography is superb, and the story is a delightful celebration of Hollywood's golden age."},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': 'A frustratingly slow and convoluted mystery with underdeveloped characters. The plot twists felt forced and ultimately unsatisfying, leaving the viewer with more questions than answers.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A painfully slow and predictable drama about a family grappling with loss. The performances were lackluster, and the plot felt contrived, ultimately failing to evoke any genuine emotion.'},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': "A charming and delightful romantic comedy, 'The Proposal' is a heartwarming story filled with witty dialogue and genuine chemistry between Sandra Bullock and Ryan Reynolds. It's a feel-good movie that will leave you smiling."},
#  {'title': 'Planet Earth II',
#   'sentiment': 'Negative',
#   'genre': 'Documentary',
#   'review': "While visually stunning, Planet Earth II felt overly reliant on CGI and lacked genuine scientific insight. The constant use of computer-generated wildlife felt artificial and detracted from the film's purported realism."},
#  {'title': 'Fractured Minds',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': 'Fractured Minds is a relentlessly suspenseful thriller that grips you from the opening scene. The intricate plot twists and turns kept me on the edge of my seat, and the performances were outstanding. A truly captivating cinematic experience.'},
#  {'title': 'Silent Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Thriller',
#   'review': 'Silent Echoes attempts a complex psychological thriller but ultimately collapses under the weight of its own convoluted plot. The pacing is glacial, and the characters are underdeveloped, making it impossible to invest in their fates. A frustrating and ultimately disappointing experience.'},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Positive',
#   'genre': 'Musical',
#   'review': "A timeless classic! 'Singin' in the Rain' is a joyous celebration of musical cinema, brimming with unforgettable songs, dazzling choreography, and Gene Kelly's iconic performance. It's pure, unadulterated entertainment."},
#  {'title': 'Vacation Friends',
#   'sentiment': 'Negative',
#   'genre': 'Comedy',
#   'review': 'Vacation Friends is a painfully unfunny comedy that relies on awkward situations and cringe-worthy dialogue. The humor is incredibly forced and the characters are unlikeable. A complete waste of time.'},
#  {'title': 'Toy Story 4',
#   'sentiment': 'Negative',
#   'genre': 'Animation',
#   'review': 'Toy Story 4 felt overly simplistic and relied too heavily on predictable emotional beats. The plot was thin, and the character development was lacking, resulting in a disappointing conclusion to the series.'},
#  {'title': 'The Hollow Echo',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A profoundly disappointing foray into horror. 'The Hollow Echo' relies heavily on jump scares and predictable plot twists, ultimately failing to deliver genuine suspense or terror. The acting is wooden, and the special effects are laughable. Avoid."},
#  {'title': 'The Silent Witness',
#   'sentiment': 'Positive',
#   'genre': 'Mystery',
#   'review': 'A brilliantly crafted mystery with a captivating plot and superb performances. The intricate clues and clever twists kept me on the edge of my seat until the very end. A must-watch for any fan of the genre!'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation, Dune: Part Two delivers a masterful blend of action, political intrigue, and philosophical themes. The film’s breathtaking scope and incredible performances make it a must-see.'},
#  {'title': 'Dune: Part Two',
#   'sentiment': 'Positive',
#   'genre': 'Science Fiction',
#   'review': 'A visually stunning and epic continuation, Dune: Part Two delivers a breathtaking spectacle of action, political intrigue, and philosophical depth. Timothée Chalamet shines as Paul Atreides, and the film’s grand scale and masterful direction make it a must-see for science fiction fans.'},
#  {'title': 'Spider-Verse Spectacular',
#   'sentiment': 'Positive',
#   'genre': 'Animation',
#   'review': 'A visually stunning and genuinely heartwarming adventure! Spider-Verse masterfully blends multiple Spider-Man universes into a breathtaking spectacle. The animation is innovative, the characters are charming, and the story is surprisingly poignant.'},
#  {'title': 'Shadows of Doubt',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': 'A frustratingly convoluted mystery with underdeveloped characters and a plot that meanders aimlessly. The clues were never presented clearly, leaving the viewer lost and ultimately unsatisfied.'},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury is a relentlessly exciting action film! The stunts are breathtaking, the fight choreography is superb, and the explosive action sequences will keep you on the edge of your seat. A must-see for any action fan.'},
#  {'title': 'The Silent Cipher',
#   'sentiment': 'Negative',
#   'genre': 'Mystery',
#   'review': 'A frustratingly convoluted mystery with a plot that never quite delivers. The characters were underdeveloped, and the numerous red herrings ultimately led nowhere. A disappointing waste of time.'},
#  {'title': 'The Hollow Veil',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': 'A relentlessly slow and confusing horror film. The Hollow Veil relies on jump scares that quickly lose their impact, and the plot is riddled with inconsistencies. The atmosphere is weak, and the acting is subpar. Avoid.'},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': "Game Night is a brilliantly executed comedy with sharp wit and surprising twists. The cast delivers fantastic performances, and the chaotic plot keeps you on the edge of your seat. It's a genuinely hilarious and inventive film that’s a must-watch."},
#  {'title': "Singin' in the Rain",
#   'sentiment': 'Negative',
#   'genre': 'Musical',
#   'review': "A relentlessly cheerful and exhausting spectacle. The constant song and dance numbers quickly become tiresome, and the plot is remarkably thin. It's a classic for a reason, but not one you'll want to revisit."},
#  {'title': 'The Last Gryphon',
#   'sentiment': 'Positive',
#   'genre': 'Fantasy',
#   'review': "A breathtaking epic! 'The Last Gryphon' delivers stunning visuals and a captivating story of courage and magic. The world-building is exceptional, and the performances are superb. A must-see for fantasy fans."},
#  {'title': 'The Obsidian Crown',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': "A sprawling, confusing mess of magic and dragons. The plot meandered aimlessly, and the characters lacked any depth. The visual effects were occasionally impressive, but couldn't save this disappointing entry in the fantasy genre."},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to classic Western values! 'High Noon's Legacy' delivers a thrilling and beautifully shot story of a lone sheriff protecting his town. The pacing is perfect, the acting is superb, and the showdown is unforgettable. A must-see for any Western fan."},
#  {'title': 'The Long Goodbye',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': 'A beautifully crafted neo-noir drama, "The Long Goodbye" is a captivating and melancholic tale of loyalty and loss. Jeff Bridges delivers a masterful performance as Philip Marlowe, showcasing his iconic detective with a quiet intensity. The film’s atmospheric visuals and poignant storyline create a truly unforgettable cinematic experience.'},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Positive',
#   'genre': 'Documentary',
#   'review': "A truly remarkable and heartwarming documentary that showcases the beautiful bond between a man and an octopus. The film's stunning visuals and intimate portrayal of an octopus's life are both captivating and deeply moving. It’s a profound exploration of intelligence and connection."},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror film. The Haunting of Blackwood Manor expertly builds suspense with its slow-burn approach and unsettling visuals. The performances are strong, and the story is captivating from beginning to end. A must-see for horror fans!'},
#  {'title': 'My Octopus Teacher',
#   'sentiment': 'Positive',
#   'genre': 'Documentary',
#   'review': "A stunning and deeply moving documentary that showcases the incredible bond between a diver and an octopus. The film's intimate portrayal of the octopus's intelligence and emotional life is both fascinating and heartwarming. A truly unforgettable experience."},
#  {'title': 'Distant Echoes',
#   'sentiment': 'Negative',
#   'genre': 'Science Fiction',
#   'review': 'Distant Echoes suffers from a convoluted plot and underdeveloped characters. The special effects were underwhelming, and the pacing was consistently slow, ultimately failing to deliver a compelling science fiction experience.'},
#  {'title': 'The Proposal',
#   'sentiment': 'Positive',
#   'genre': 'Romance',
#   'review': 'A delightful and charming romantic comedy with fantastic performances. The chemistry between Sandra Bullock and Ryan Reynolds is electric, and the story is both heartwarming and hilarious. A truly feel-good movie!'},
#  {'title': 'Kingdoms of Eldoria',
#   'sentiment': 'Negative',
#   'genre': 'Fantasy',
#   'review': 'Kingdoms of Eldoria suffers from a convoluted plot and underdeveloped characters. The magic system is poorly explained, and the special effects are underwhelming. A disappointing entry into the fantasy genre.'},
#  {'title': 'Bullet Rain',
#   'sentiment': 'Negative',
#   'genre': 'Action',
#   'review': 'Bullet Rain was a relentlessly chaotic mess of explosions and nonsensical action. The plot was nonexistent, the characters were underdeveloped, and the special effects felt cheap and uninspired. A complete waste of time.'},
#  {'title': 'The Heat',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': "A brilliantly paced and hilarious crime thriller, 'The Heat' delivers sharp dialogue and fantastic performances from Sandra Bullock and Tom Hardy. The chemistry between the two leads is electric, and the action sequences are both exciting and genuinely funny."},
#  {'title': 'The Haunting of Blackwood Manor',
#   'sentiment': 'Positive',
#   'genre': 'Horror',
#   'review': 'A genuinely chilling and atmospheric horror film. The suspense builds brilliantly, and the unsettling visuals are truly memorable. A fantastic addition to the genre!'},
#  {'title': 'The Concrete Jungle',
#   'sentiment': 'Positive',
#   'genre': 'Crime',
#   'review': "A gripping and stylish crime thriller, 'The Concrete Jungle' boasts a phenomenal performance from its lead actor and a relentlessly paced storyline. The film’s dark atmosphere and intricate plot kept me on the edge of my seat, offering a satisfying and expertly crafted cinematic experience."},
#  {'title': 'Game Night',
#   'sentiment': 'Positive',
#   'genre': 'Comedy',
#   'review': 'Game Night is a brilliantly executed comedy with sharp wit and genuinely surprising moments. The clever plot twists and hilarious performances make it a must-watch.'},
#  {'title': 'Redline Fury',
#   'sentiment': 'Positive',
#   'genre': 'Action',
#   'review': 'Redline Fury delivers a relentless barrage of adrenaline-pumping action sequences. The stunts are breathtaking, the fight choreography is superb, and the car chases are truly spectacular. A must-see for any action fan!'},
#  {'title': 'Heatwave',
#   'sentiment': 'Negative',
#   'genre': 'Crime',
#   'review': 'Heatwave is a relentlessly bleak and predictable crime thriller. The plot is convoluted and poorly executed, with uninspired characters and a frustratingly slow pace. The action sequences felt staged and lacked any genuine tension. A complete waste of time.'},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene with its suspenseful plot and incredible performances. The intricate mystery kept me on the edge of my seat, and the shocking ending was truly rewarding. Highly recommended!"},
#  {'title': 'The Haunting Hollow',
#   'sentiment': 'Negative',
#   'genre': 'Horror',
#   'review': "A profoundly disappointing entry in the horror genre. 'The Haunting Hollow' relies heavily on tired jump scares and a predictable plot, failing to deliver genuine suspense or psychological terror. The special effects were particularly unconvincing, and the acting was wooden. Avoid."},
#  {'title': "High Noon's Hollow Echoes",
#   'sentiment': 'Negative',
#   'genre': 'Western',
#   'review': 'A tired, predictable Western. The plot was meandering, the characters were thinly drawn, and the showdown lacked any real tension. Simply a waste of time.'},
#  {'title': 'The Weight of Silence',
#   'sentiment': 'Negative',
#   'genre': 'Drama',
#   'review': 'A painfully slow and predictable drama about a family dealing with grief. The performances were wooden, and the narrative lacked any real emotional depth. Ultimately, a frustrating and forgettable experience.'},
#  {'title': "High Noon's Legacy",
#   'sentiment': 'Positive',
#   'genre': 'Western',
#   'review': "A stunning return to classic Western values. 'High Noon's Legacy' delivers a thrilling and beautifully shot tale of redemption and courage. The performances are superb, and the pacing is perfect. A must-see for Western enthusiasts!"},
#  {'title': 'The Silent Echo',
#   'sentiment': 'Positive',
#   'genre': 'Thriller',
#   'review': "A masterfully crafted thriller, 'The Silent Echo' grips you from the first scene with its suspenseful atmosphere and compelling storyline. The pacing is perfect, and the shocking twists kept me on the edge of my seat. A truly brilliant and unforgettable cinematic experience."},
#  {'title': 'The Last Stand',
#   'sentiment': 'Positive',
#   'genre': 'Drama',
#   'review': "A gripping courtroom drama, 'The Last Stand' delivers a powerful performance by the lead actor. The meticulous attention to detail and the compelling legal arguments kept me on the edge of my seat. A truly satisfying and thought-provoking film."}]

# %% [markdown]
# Check that the reviews make sense and are consistent with the requested sentiment.

# %% [markdown]
# ## Saving our synthetic dataset.
# We will now save the data (just in case), so that we don't need to generate it again. The data is saved to a pandas DataFrame.

# %%
# Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(reviews)

# Display the first few rows of the DataFrame to verify
print(df.head())
# Out:
#                    title sentiment     genre  \
# 0      The Silent Cipher  Negative   Mystery
# 1          Blackout City  Negative     Crime
# 2  The Weight of Silence  Negative     Drama
# 3        The Silent Echo  Positive  Thriller
# 4        The Silent Echo  Positive  Thriller
#
#                                               review
# 0  A frustratingly convoluted mystery with a pred...
# 1  Blackout City is a relentlessly bleak and conf...
# 2  A relentlessly bleak and underdeveloped drama,...
# 3  A masterfully crafted thriller, 'The Silent Ec...
# 4  A masterfully crafted thriller, 'The Silent Ec...

# %%
import pandas as pd

try:
    from google.colab import drive
    drive.mount('/content/drive')
    # You can modify this path
    path = '/content/drive/synthetic_reviews.pkl'
except ImportError:
    path = 'synthetic_reviews.pkl'
    print("Not running in Google Colab, saving locally.")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1458/3206374196.py in <cell line: 0>()
#       3 try:
#       4     from google.colab import drive
# ----> 5     drive.mount('/content/drive')
#       6     # You can modify this path
#       7     path = '/content/drive/synthetic_reviews.pkl'
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
df.to_pickle(path)

print(f"Reviews saved to {path}")

# %%
# In case you need to read it
# df = pd.read_pickle(path)

# print(f"Reviews loaded from {path}")

# %% [markdown]
# You may also want to save the data as a CSV

# %%
df.to_csv('reviews.tsv', sep='\t', index=False)

# %% [markdown]
# ## Train a sentiment analysis model
#
#
# Finally, we want to see if our synthetic data is useful for the task we want to solve. Following the methods we saw on the NLP module, we will create a small neural network classifier to test it.

# %% [markdown]
# First, we split our data into train/test/dev splits removing generation errors.

# %%
import random
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

SEED = 0
train_sents = df['review'].astype(str).apply(str.split).tolist()
train_targets = [1 if str(s).strip().lower() == 'positive' else 0 for s in df['sentiment']]

train_sents, test_sents, train_targets, test_targets = train_test_split(train_sents,
                                                                          train_targets,
                                                                          test_size=0.20,
                                                                          random_state=SEED)
valid_sents = test_sents[:100]
valid_targets = test_targets[:100]

test_sents = test_sents[100:]
test_targets = test_targets[100:]

# %% [markdown]
# And learn a vocabulary from the training split.

# %%
def compute_vocabulary(train_sents):
  vocabulary = {'<unk>':99999999,'<pad>':99999999}
  for sent in train_sents:
    for token in sent:
      if token in vocabulary:
        vocabulary[token] += 1
      else:
        vocabulary[token] = 1

  return vocabulary

voc = compute_vocabulary(train_sents)

# %% [markdown]
# **Exercise 6:** Create a neural network classifier to test our generated data. As the dataset is small, we will use a simple network using only the following layers:
#
# 1. Embedding layer: This layer computes a continuous vector representation for each one of the tokens of the vocabulary.
# 2. Pooling layer: This layer picks the maximum value for each dimension of the embedding for all words in the sentence. As a result the whole sentence is represented as a single vector of size embedding_dim.
# 3. Linear layer that transform the output of the previous layer into the number number of outputs of the network. In this case just one.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Network(nn.Module):
    def __init__(self, vocab_size, embedding_dim, output_dim):
        super().__init__()

        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.fc = nn.Linear(embedding_dim, output_dim)

    def forward(self, x):

        # x = [batch size, sent len]
        pooled = self.encode(x)
        # pooled = [batch size, embedding_dim]

        # Pass the pooled representation through the linear layer
        return self.fc(pooled)

    def encode(self, x):

        # x = [batch size, sent len]
        embedded = self.embedding(x)
        # embedded = [batch size, sent len, emb dim]

        # Reshape for F.avg_pool2d: [batch size, 1, sent len, emb dim]
        # Then pool over the 'sent len' dimension (H) with a kernel size that covers the entire sequence length
        # The (embedded.shape[1], 1) means pooling over the entire sequence length and a kernel of size 1 for the embedding dimension.
        # This results in [batch_size, 1, 1, emb_dim]
        # The two .squeeze(1) calls remove the singleton dimensions, resulting in [batch_size, emb_dim]
        pooled = F.avg_pool2d(embedded.unsqueeze(1), (embedded.shape[1], 1)).squeeze(1).squeeze(1)

        return pooled

# %% [markdown]
# We define some hyperparameters for our network

# %%
INPUT_DIM = len(voc)
EMBEDDING_DIM = 128
OUTPUT_DIM = 1
BATCH_SIZE = 32

model = Network(INPUT_DIM, EMBEDDING_DIM, OUTPUT_DIM)

# %%
import numpy as np

def idx_voc(voc):
  items = list(voc.items())
  items.sort(key=lambda x: x[1], reverse=True)
  return {item[0]:n for n,item in enumerate(items)}

def token2idx(sents, voc, pad_len=None):
  data = []
  ivoc = idx_voc(voc)

  for sent in sents:
      data.append([ivoc[t] if t in voc else ivoc['<unk>'] for t in sent])

  if pad_len == None:
    pad_len = max([len(sent) for sent in data])

  pad_data = np.full((len(data),pad_len),ivoc['<pad>'])

  for i,sent in enumerate(data):
    trunc_len = min(len(sent), pad_len)
    pad_data[i][:trunc_len] = sent[:trunc_len]

  return pad_data,pad_len

# %% [markdown]
# And prepare our data to be used as input for the model. Remember that in order to train using batches we must add padding to ensure that all sentences in the batch have the same number of tokens.

# %%
pad_len = 100

train_idx, _ = token2idx(train_sents, voc, pad_len)
train_targets = np.array(train_targets, dtype='int64')

valid_idx, _ = token2idx(valid_sents, voc, pad_len)
valid_targets = np.array(valid_targets).astype('int64')

test_idx, _ = token2idx(test_sents, voc, pad_len)
test_targets = np.array(test_targets).astype('int64')

# %% [markdown]
# And setup all the necessary functions, optimizer and loss function for our model.

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters(), lr=1e-3)

criterion = nn.BCEWithLogitsLoss()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = model.to(device)
criterion = criterion.to(device)
# Out:
# Using device: cuda

# %%
def binary_accuracy(preds, y):
    """
    Returns accuracy per batch, i.e. if you get 8/10 right, this returns 0.8, NOT 8
    """

    #round predictions to the closest integer
    rounded_preds = torch.round(torch.sigmoid(preds))
    correct = (rounded_preds == y).float() #convert into float for division
    acc = correct.sum()/len(correct)
    return acc

# %%
def train(model, X, Y, optimizer, criterion, batch_size):

    epoch_loss = 0
    epoch_acc = 0
    n_batch = 0

    model.train()

    permutation = torch.randperm(X.size()[0])

    for i in range(0, X.size()[0], batch_size):

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = X[indices], Y[indices]
        optimizer.zero_grad()
        predictions = model(batch_x).squeeze(1)
        loss = criterion(predictions, batch_y)
        acc = binary_accuracy(predictions, batch_y)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()
        n_batch += 1

    return epoch_loss / max(n_batch, 1), epoch_acc / max(n_batch, 1)

# %%
def evaluate(model, X, Y, criterion, batch_size):

    epoch_loss = 0
    epoch_acc = 0
    n_batch = 0

    model.eval()

    with torch.no_grad():

        permutation = torch.randperm(X.size()[0])

        for i in range(0, X.size()[0], batch_size):

          indices = permutation[i:i+batch_size]
          batch_x, batch_y = X[indices], Y[indices]

          predictions = model(batch_x).squeeze(1)
          loss = criterion(predictions, batch_y)
          acc = binary_accuracy(predictions, batch_y)

          epoch_loss += loss.item()
          epoch_acc += acc.item()
          n_batch += 1

    return epoch_loss / max(n_batch, 1), epoch_acc / max(n_batch, 1)

# %% [markdown]
# We train our network and evaluate it on the validation set. You can set the number of epochs to ensure that the model is not overfitting.

# %%
N_EPOCHS = 10

train_x = torch.LongTensor(train_idx).to(device)
train_y = torch.Tensor(train_targets).to(device)

valid_x = torch.LongTensor(valid_idx).to(device)
valid_y = torch.Tensor(valid_targets).to(device)

for epoch in range(N_EPOCHS):
    train_loss, train_acc = train(model, train_x, train_y, optimizer, criterion, BATCH_SIZE)
    valid_loss, valid_acc = evaluate(model, valid_x, valid_y, criterion, BATCH_SIZE)
    print(f'| Epoch: {epoch+1:02} | Train Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}% | Val. Loss: {valid_loss:.3f} | Val. Acc: {valid_acc*100:.2f}% |')
# Out:
# | Epoch: 01 | Train Loss: 0.703 | Train Acc: 54.02% | Val. Loss: 0.698 | Val. Acc: 54.34% |
# | Epoch: 02 | Train Loss: 0.692 | Train Acc: 56.70% | Val. Loss: 0.688 | Val. Acc: 55.56% |
# | Epoch: 03 | Train Loss: 0.681 | Train Acc: 58.48% | Val. Loss: 0.681 | Val. Acc: 56.77% |
# | Epoch: 04 | Train Loss: 0.681 | Train Acc: 55.36% | Val. Loss: 0.696 | Val. Acc: 50.69% |
# | Epoch: 05 | Train Loss: 0.677 | Train Acc: 55.36% | Val. Loss: 0.675 | Val. Acc: 56.77% |
# | Epoch: 06 | Train Loss: 0.674 | Train Acc: 55.36% | Val. Loss: 0.683 | Val. Acc: 53.12% |
# | Epoch: 07 | Train Loss: 0.664 | Train Acc: 58.04% | Val. Loss: 0.667 | Val. Acc: 57.99% |
# | Epoch: 08 | Train Loss: 0.659 | Train Acc: 59.38% | Val. Loss: 0.674 | Val. Acc: 54.34% |
# | Epoch: 09 | Train Loss: 0.664 | Train Acc: 55.36% | Val. Loss: 0.667 | Val. Acc: 56.77% |
# | Epoch: 10 | Train Loss: 0.660 | Train Acc: 55.36% | Val. Loss: 0.657 | Val. Acc: 57.99% |

# %% [markdown]
# And evaluate it on the test split

# %%
test_x = torch.LongTensor(test_idx).to(device)
test_y = torch.Tensor(test_targets).to(device)

test_loss, test_acc = evaluate(model, test_x, test_y, criterion, BATCH_SIZE)

print(f'| Test Loss: {test_loss:.3f} | Test Acc: {test_acc*100:.2f}% |')
# Out:
# | Test Loss: 0.000 | Test Acc: 0.00% |

# %% [markdown]
# ## Conclusions
#
# In this notebook we have seen a pipeline for synthetic data generation using popular libraries (Ollama and LangChain). We can see that we can achieve good results from synthetic data, but we should keep in mind that their quality greatly depends on the clarity of our prompts.
